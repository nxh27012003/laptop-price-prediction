# %%
import pandas as pd
import csv

# %%
df = pd.read_csv("../laptop-prices-analysis/Data/amazon_temporary.csv", i)

# %%
df_integrated = pd.read_csv("integrated.csv", index_col = 0)
df_integrated.head()
# Out:
#   Brand          Series                                        CPU  \
# 0  acer   A314-23P-R3QA          AMD Ryzen 5 Ryzen 5 7520U 4.3 GHz
# 1    HP   HP Chromebook   Intel Pentium Intel Processor N200 1 GHz
# 2  acer          Laptop          AMD Ryzen 3 Ryzen 3 7320U 4.1 GHz
# 3    HP     14-dq0040nr          Intel Celeron N4020 N4020 2.8 GHz
# 4  ASUS  Vivobook Go 14  Intel Celeron Intel Celeron N4020 2.8 GHz
#
#                    GPU   RAM      Monitor          Resolution     Storage  \
# 0                  AMD  8 GB    14 Inches  1920 x 1080 pixels  512 GB SSD
# 1                Intel  8 GB  15.6 Inches   1366 x 768 pixels   64 GB SSD
# 2  AMD Radeon Graphics  8 GB  15.6 Inches  1920 x 1080 pixels  128 GB SSD
# 3   Intel UHD Graphics  4 GB    14 Inches   1366 x 768 pixels   64 GB SSD
# 4                Intel  4 GB     4 Inches  1920 x 1080 pixels         NaN
#
#                   OS       Weight   Price
# 0    Windows 11 Home  3.09 Pounds  349.99
# ...

# %%
df_dedicated = pd.read_csv("dedicated.csv", index_col = 0)
df_dedicated.tail()
# Out:
#      Brand            Series  \
# 1915  DELL          G15 5520
# 1916  Dell          G15 5520
# 1917   MSI  Pulse GL76 12UEK
# 1918   MSI   MSI GE66 Raider
# 1919  Dell            XPS 17
#
#                                                     CPU  \
# 1915  Intel Core i7 Family Intel Core i7-12700H 2.5 GHz
# 1916  Intel Core i7 Family Intel Core i7-12700H 2.5 GHz
# 1917  Intel Core i7 Family Intel Core i7-12700H 2.6 GHz
# 1918                              Intel Core i7 2.6 GHz
# 1919    Intel Core i7 Family Intel Core i7-12700H 3 GHz
#
#                           GPU    RAM      Monitor          Resolution  \
# 1915  NVIDIA GeForce RTX 3060  16 GB  15.6 Inches         1920 x 1080
# 1916  NVIDIA GeForce RTX 3060  16 GB  15.6 Inches         1920 x 1080
# 1917  NVIDIA GeForce RTX 3060  16 GB  17.3 Inches         1920 x 1080
# 1918                   NVIDEA  32 GB  15.6 Inches  1920 x 1080 pixels
# 1919  NVIDIA GeForce RTX 3060  48 GB    17 Inches         3840 x 2400
#
# ...

# %%
merged_df = pd.concat([df_integrated, df_dedicated], axis = 0, ignore_index = True)
merged_df
# Out:
#      Brand            Series  \
# 0     acer     A314-23P-R3QA
# 1       HP     HP Chromebook
# 2     acer            Laptop
# 3       HP       14-dq0040nr
# 4     ASUS    Vivobook Go 14
# ...    ...               ...
# 4203  DELL          G15 5520
# 4204  Dell          G15 5520
# 4205   MSI  Pulse GL76 12UEK
# 4206   MSI   MSI GE66 Raider
# 4207  Dell            XPS 17
#
#                                                     CPU  \
# 0                     AMD Ryzen 5 Ryzen 5 7520U 4.3 GHz
# 1              Intel Pentium Intel Processor N200 1 GHz
# 2                     AMD Ryzen 3 Ryzen 3 7320U 4.1 GHz
# 3                     Intel Celeron N4020 N4020 2.8 GHz
# 4             Intel Celeron Intel Celeron N4020 2.8 GHz
# ...                                                 ...
# 4203  Intel Core i7 Family Intel Core i7-12700H 2.5 GHz
# 4204  Intel Core i7 Family Intel Core i7-12700H 2.5 GHz
# 4205  Intel Core i7 Family Intel Core i7-12700H 2.6 GHz
# ...

# %%
merged_df = merged_df.sample(frac=1).reset_index(drop=True)
merged_df
# Out:
#        Brand                Series  \
# 0        MSI       Cyborg 15 A13VE
# 1       Dell       XPS 9530 Laptop
# 2       Dell  Latitude 7420 Laptop
# 3       Dell           Inspiron 16
# 4       DELL                XPS 15
# ...      ...                   ...
# 4203      HP      Envy x360 2-in-1
# 4204      HP           14-dq0020nr
# 4205    acer       CP7141WN57R6CBE
# 4206  Lenovo              LOQ 82XW
# 4207  Lenovo      IdeaPad 3 15ITL6
#
#                                                     CPU  \
# 0     Intel Core i7 Family Intel Core i7-13620H 3.1 GHz
# 1                                         Intel Core i9
# 2                                 Intel Core i5 0.9 GHz
# 3        Intel Core i7 Family Intel Core i7-1360P 3 GHz
# 4     Intel Core i7 Family Intel Core i7-13700H 2.9 GHz
# ...                                                 ...
# 4203     Intel Core i7 Family Intel Core i7-1355U 3 GHz
# 4204                  Intel Celeron N4020 N4020 2.8 GHz
# ...

# %% [markdown]
# # Dealing with missing values in brand

# %%
missing_brand_indices = merged_df.index[merged_df['Brand'].isna()].tolist()
# print(len(missing_brand_indices))

for i in missing_brand_indices:
    merged_df = merged_df.drop(i)

# %%
merged_df.reset_index(inplace=True)
merged_df
# Out:
#       index   Brand                Series  \
# 0         0     MSI       Cyborg 15 A13VE
# 1         1    Dell       XPS 9530 Laptop
# 2         2    Dell  Latitude 7420 Laptop
# 3         3    Dell           Inspiron 16
# 4         4    DELL                XPS 15
# ...     ...     ...                   ...
# 4199   4203      HP      Envy x360 2-in-1
# 4200   4204      HP           14-dq0020nr
# 4201   4205    acer       CP7141WN57R6CBE
# 4202   4206  Lenovo              LOQ 82XW
# 4203   4207  Lenovo      IdeaPad 3 15ITL6
#
#                                                     CPU  \
# 0     Intel Core i7 Family Intel Core i7-13620H 3.1 GHz
# 1                                         Intel Core i9
# 2                                 Intel Core i5 0.9 GHz
# 3        Intel Core i7 Family Intel Core i7-1360P 3 GHz
# 4     Intel Core i7 Family Intel Core i7-13700H 2.9 GHz
# ...                                                 ...
# 4199     Intel Core i7 Family Intel Core i7-1355U 3 GHz
# ...

# %% [markdown]
# # Handling CPU

# %% [markdown]
# # Handling GPU

# %% [markdown]
# # Handling other attributes

# %% [markdown]
# # Export CSV

# %%
merged_df.to_csv("amazon_temporary.csv")
